# %% [markdown]
# ## leemos los archivos

# %%
## partimos con el archivo en inglés

with open('Cap 1 and 2.txt', 'r', encoding='ascii', errors='ignore') as file_input:
        text = file_input.read()

# %%
text
# Out:
# 'Space and place. The Perspective of Experience\n1 Introduction\nSpace and "place" are familiar words denoting common experiences. We live in space. There is no space for another building on the lot. The Great Plains look spacious. Place is security, space is freedom: we are attached to the one and long for the other. There is no place like home. What is home? It is the old homestead, the old neighborhood, home town, or motherland. Geographers study places. Planners would like to evoke "a sense of place." These are unexceptional ways of speaking. Space and place are basic components of the lived world; we take them for granted. When we think about them, however, they may assume unexpected meanings and raise questions we have not thought to ask.\nWhat is space? Let an episode in the life of the theologian Paul Tillich focus the question so that it bears on the meaning of space in experience. Tillich was born and brought up in a small town in eastern Germany before the turn of the century. The town was medieval in character. Surrounded by a wall and administered from a medieval town hall, it gave the impression of a small, protected, and self-contained world. To an imaginative child it felt narrow and restrictive. Every year, however young Tillich was able to escape with his family to the Baltic. Sea. The flight to the limitless horizon and unrestricted space of the seashore was a great event. Much later Tillich chose a place on the Atlantic Ocean for his days of retirement, a decision that undoubtedly owed much to those early experiences. As a boy Tillich was also able to escape from the narrowness of small-town life by making trips to Berlin. Visits to the big city curiously reminded him of the sea. Berlin, too, gave Tillich a feeling of openness, infinity, unrestricted space. Experiences of this kind make us ponder anew the meaning of a word like "space" or "spaciousness" that we think we know well.\nWhat is a place? What gives a place its identity, its aura? These questions occurred to the physicists Niels Bohr and Werner Heisenberg when they visited Kronberg Castle in Denmark. Bohr said to Heisenberg:\nIsn\'t it strange how this castle changes as soon as one imagines that Hamlet lived here? As scientists we believe that a castle consists only of stones, and admire the way the architect put them together. The stones, the green roof with its patina, the wood carvings in the church, constitute the whole castle. None of this should be changed by the fact that Hamlet lived here, and yet it is changed completely. Suddenly the walls and the ramparts speak a quite different language. The courtyard becomes an entire world, a dark corner reminds us of the darkness in the human soul, we hear Hamlet\'s "To be or not to be." Yet all we really know about Hamlet is that his name appears in a thirteenth-century chronicle. No one can prove that he really lived, let alone that he lived here. But everyone knows the questions Shakespeare had him ask, the human depth he was made to reveal, and so he, too, had to be found a place on earth, here in Kronberg. And once we know that, Kronberg becomes quite a different castle for us.\nRecent ethological studies show that nonhuman animals also have a sense of territory and of place. Spaces are marked off and defended against intruders. Places are centers of felt value where biological needs, such as those for food, water, rest, and procreation, are satisfied. Humans share with other animals certain behavioral patterns, but as the reflections of Tillich and Bohr indicate, people also respond to space and place in complicated ways that are inconceivable in the animal world. How can the Baltic Sea and Berlin both evoke a sense of openness and infinitude? How can a mere legend haunt Kronberg Castle and impart a mood that infiltrates the minds of two famous scientists? If our concern with the nature and quality of the human environment is serious, these are surely basic questions. Yet they have seldom been ...

# %% [markdown]
# ## limpiamos un poco el texto

# %%
## función para limpiar los textos
import string
import re
from nltk import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')

## stopwords
stop_words = set(stopwords.words('english'))
## lematizador
lemmatizer = WordNetLemmatizer()

## texto es un string
def clean(texto):
    
    ## dividimos por salto de línea
    texto = texto.split('\n')
    ## algunos caracteres 
    texto = [T.replace('\n', '') for T in texto]
    ## puntuación
    texto = [sent_tokenize(T) for T in texto]
    ## flat list de oraciones
    texto = [item for sublist in texto for item in sublist]
    ## puntuación
    texto = [T.translate(str.maketrans('', '', string.punctuation+'¿'+'—'+'”'+'“'+'!'+'¡')) for T in texto]
    ## removemos números
    texto = [''.join([i for i in T if not i.isdigit()]) for T in texto]
    ## espacios en blanco extra y ponemos en minúscula
    texto = [re.sub(' +', ' ', T).strip().lower() for T in texto]
    ## divimos en palabras
    texto = [T.split(' ') for T in texto]
    ## eliminamos stopwords
    texto = [[word for word in T if word not in stop_words] for T in texto]
    ## eliminamos oraciones de largo 1
    texto = [T for T in texto if len(T)>1]
    ## lematizador
    texto = [[lemmatizer.lemmatize(word) for word in T] for T in texto]
    
    return texto
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jxver\AppData\Roaming\nltk_data...

# %%
text = clean(text)

# %%
text
# Out:
# [['space', 'place'],
#  ['perspective', 'experience'],
#  ['space', 'place', 'familiar', 'word', 'denoting', 'common', 'experience'],
#  ['live', 'space'],
#  ['space', 'another', 'building', 'lot'],
#  ['great', 'plain', 'look', 'spacious'],
#  ['place', 'security', 'space', 'freedom', 'attached', 'one', 'long'],
#  ['place', 'like', 'home'],
#  ['old', 'homestead', 'old', 'neighborhood', 'home', 'town', 'motherland'],
#  ['geographer', 'study', 'place'],
#  ['planner', 'would', 'like', 'evoke', 'sense', 'place'],
#  ['unexceptional', 'way', 'speaking'],
#  ['space', 'place', 'basic', 'component', 'lived', 'world', 'take', 'granted'],
#  ['think',
#   'however',
#   'may',
#   'assume',
#   'unexpected',
#   'meaning',
#   'raise',
#   'question',
#   'thought',
#   'ask'],
#  ['let',
#   'episode',
#   'life',
#   'theologian',
#   'paul',
#   'tillich',
#   'focus',
#   'question',
#   'bear',
#   'meaning',
#   'space',
#   'experience'],
#  ['tillich',
#   'born',
#   'brought',
#   'small',
#   'town',
#   'eastern',
#   'germany',
#   'turn',
#   'century'],
#  ['town', 'medieval', 'character'],
#  ['surrounded',
#   'wall',
#   'administered',
#   'medieval',
#   'town',
#   'hall',
#   'gave',
#   'impression',
#   'small',
#   'protected',
#   'selfcontained',
#   'world'],
#  ['imaginative', 'child', 'felt', 'narrow', 'restrictive'],
#  ['every',
#   'year',
#   'however',
#   'young',
#   'tillich',
#   'able',
#   'escape',
#   'family',
#   'baltic'],
#  ['flight',
#   'limitless',
#   'horizon',
#   'unrestricted',
#   'space',
#   'seashore',
#   'great',
#   'event'],
#  ['much',
#   'later',
#   'tillich',
#   'chose',
#   'place',
#   'atlantic',
#   'ocean',
#   'day',
#   'retirement',
#   'decision',
#   'undoubtedly',
#   'owed',
#   'much',
#   'early',
#   'experience'],
#  ['boy',
#   'tillich',
#   'also',
#   'able',
#   'escape',
#   'narrowness',
#   'smalltown',
#   'life',
#   'making',
#   'trip',
#   'berlin'],
#  ['visit', 'big', 'city', 'curiously', 'reminded', 'sea'],
#  ['berlin',
#   'gave',
#   'tillich',
#   'feeling',
#   'openness',
#   'infinity',
#   'unrestricted',
#   'space'],
#  ['experience',
#   'kind',
#   'make',
#   'u',
#   'ponder',
#   'anew',
#   'meaning',
#   'word',
#   'like',
#   'space',
#   'spaciousness',
#   'think',
#   'know',
#   'well'],
#  ['give', 'place', 'identity', 'aura'],
#  ['question',
#   'occurred',
#   'physicist',
#   'niels',
#   'bohr',
#   'werner',
#   'heisenberg',
#   'visited',
#   'kronberg',
#   'castle',
#   'denmark'],
#  ['bohr', 'said', 'heisenberg'],
#  ['isnt',
#   'strange',
#   'castle',
#   'change',
#   'soon',
#   'one',
#   'imago',
#   'hamlet',
#   'lived'],
#  ['scientist',
#   'believe',
#   'castle',
#   'consists',
#   'stone',
#   'admire',
#   'way',
#   'architect',
#   'put',
#   'together'],
#  ['stone',
#   'green',
#   'roof',
#   'patina',
#   'wood',
#   'carving',
#   'church',
#   'constitute',
#   'whole',
#   'castle'],
#  ['none',
#   'changed',
#   'fact',
#   'hamlet',
#   'lived',
#   'yet',
#   'changed',
#   'completely'],
#  ['suddenly', 'wall', 'rampart', 'speak', 'quite', 'different', 'language'],
#  ['courtyard',
#   'becomes',
#   'entire',
#   'world',
#   'dark',
#   'corner',
#   'reminds',
#   'u',
#   'darkness',
#   'human',
#   'soul',
#   'hear',
#   'hamlet'],
#  ['yet',
#   'really',
#   'know',
#   'hamlet',
#   'name',
#   'appears',
#   'thirteenthcentury',
#   'chronicle'],
#  ['one', 'prove', 'really', 'lived', 'let', 'alone', 'lived'],
#  ['everyone',
#   'know',
#   'question',
#   'shakespeare',
#   'ask',
#   'human',
#   'depth',
#   'made',
#   'reveal',
#   'found',
#   'place',
#   'earth',
#   'kronberg'],
#  ['know', 'kronberg', 'becomes', 'quite', 'different', 'castle', 'u'],
#  ['recent',
#   'ethological',
#   'study',
#   'show',
#   'nonhuman',
#   'animal',
#   'also',
#   'sense',
#   'territory',
#   'place'],
#  ['space', 'marked', 'defended', 'intruder'],
#  ['place',
#   'center',
#   'felt',
#   'value',
#   'biological',
#   'need',
#   'food',
#   'water',
#   'rest',
#   'procreation',
#   'satisfied'],
#  ['human',
#   'share',
#   'animal',
#   'certain',
#   'behavioral',
#   'pattern',
#   'reflection',
#   'tillich',
#   'bohr',
#   'indicate',
#   'people',
#   'also',
#   'respond',
#   'space',
#   'place',
#   'complicated',
#   'way',
#   'inconceivable',
#   'animal',
#   'world'],
#  ['baltic', 'sea', 'berlin', 'evoke', 'sense', 'openness', 'infinitude'],
#  ['mere',
#   'legend',
#   'haunt',
#   'kronberg',
#   'castle',
#   'impart',
#   'mood',
#   'infiltrates',
#   'mind',
#   'two',
#   'famous',
#   'scientist'],
#  ['concern',
#   'nature',
#   'quality',
#   'human',
#   'environment',
#   'serious',
#   'surely',
#   'basic',
#   'question'],
#  ['yet', 'seldom', 'raised'],
#  ['instead',
#   'study',
#   'animal',
#   'rat',
#   'wolf',
#   'say',
#   'human',
#   'behavior',
#   'value',
#   'much',
#   'like'],
#  ['measure',
#   'map',
#   'space',
#   'place',
#   'acquire',
#   'spatial',
#   'law',
#   'resource',
#   'inventory',
#   'effort'],
#  ['important',
#   'approach',
#   'need',
#   'complemented',
#   'experiential',
#   'data',
#   'collect',
#   'interpret',
#   'measured',
#   'confidence',
#   'human'],
#  ['privileged', 'access', 'state', 'mind', 'thought', 'feeling'],
#  ['insider',
#   'view',
#   'human',
#   'fact',
#   'claim',
#   'cannot',
#   'make',
#   'regard',
#   'kind',
#   'fact'],
#  ['people', 'sometimes', 'behave', 'like', 'cornered', 'wary', 'animal'],
#  ['occasion',
#   'may',
#   'also',
#   'act',
#   'like',
#   'cool',
#   'scientist',
#   'dedicated',
#   'task',
#   'formulating',
#   'law',
#   'mapping',
#   'resource'],
#  ['neither', 'posture', 'hold', 'sway', 'long'],
#  ['people', 'complex', 'being'],
#  ['human',
#   'endowment',
#   'includes',
#   'sensory',
#   'organ',
#   'similar',
#   'primate',
#   'capped',
#   'exceptionally',
#   'refined',
#   'capacity',
#   'symbolization'],
#  ['human',
#   'person',
#   'animal',
#   'fantasist',
#   'computer',
#   'combined',
#   'experience',
#   'understands',
#   'world',
#   'central',
#   'theme',
#   'book'],
#  ['given',
#   'human',
#   'endowment',
#   'way',
#   'people',
#   'attach',
#   'meaning',
#   'organize',
#   'space',
#   'place'],
#  ['question',
#   'asked',
#   'social',
#   'scientist',
#   'tempted',
#   'rush',
#   'culture',
#   'explanatory',
#   'factor'],
#  ['culture', 'uniquely', 'developed', 'human', 'being'],
#  ['strongly', 'influence', 'human', 'behavior', 'value'],
#  ['eskimo', 'sense', 'space', 'place', 'different', 'american'],
#  ['approach',
#   'valid',
#   'overlook',
#   'problem',
#   'shared',
#   'trait',
#   'transcend',
#   'cultural',
#   'particularity',
#   'may',
#   'therefore',
#   'reflect',
#   'general',
#   'human',
#   'condition'],
#  ['note',
#   'taken',
#   'universal',
#   'behavioral',
#   'scientist',
#   'likely',
#   'turn',
#   'analogue',
#   'primate',
#   'behayior'],
#  ['book', 'animal', 'heritage', 'assumed'],
#  ['importance',
#   'culture',
#   'taken',
#   'granted',
#   'culture',
#   'inescapable',
#   'explored',
#   'every',
#   'chapter'],
#  ['purpose',
#   'essay',
#   'produce',
#   'handbook',
#   'culture',
#   'affect',
#   'human',
#   'attitude',
#   'space',
#   'place'],
#  ['essay',
#   'rather',
#   'prologue',
#   'culture',
#   'countless',
#   'variety',
#   'focus',
#   'general',
#   'question',
#   'human',
#   'disposition',
#   'capacity',
#   'need',
#   'culture',
#   'emphasizes',
#   'distorts'],
#  ['three', 'theme', 'weave', 'essay'],
#  ['biological', 'fact'],
#  ['human', 'infant', 'crude', 'notion', 'space', 'place'],
#  ['time', 'acquire', 'sophistication'],
#  ['stage', 'learning'],
#  ['human', 'body', 'lie', 'prone', 'upright'],
#  ['upright', 'top', 'bottom', 'front', 'back', 'right', 'left'],
#  ['bodily',
#   'posture',
#   'division',
#   'value',
#   'extrapolated',
#   'onto',
#   'circumambient',
#   'space'],
#  ['relation', 'space', 'place'],
#  ['experience', 'meaning', 'space', 'often', 'merges', 'place'],
#  ['space', 'abstract', 'place'],
#  ['begin',
#   'undifferentiated',
#   'space',
#   'becomes',
#   'place',
#   'get',
#   'know',
#   'better',
#   'endow',
#   'value'],
#  ['architect',
#   'talk',
#   'spatial',
#   'quality',
#   'place',
#   'equally',
#   'well',
#   'speak',
#   'locational',
#   'place',
#   'quality',
#   'space'],
#  ['idea', 'space', 'place', 'require', 'definition'],
#  ['security',
#   'stability',
#   'place',
#   'aware',
#   'openness',
#   'freedom',
#   'threat',
#   'space',
#   'vice',
#   'versa'],
#  ['furthermore',
#   'think',
#   'space',
#   'allows',
#   'movement',
#   'place',
#   'pause',
#   'pause',
#   'movement',
#   'make',
#   'possible',
#   'location',
#   'transformed',
#   'place'],
#  ['range', 'experience', 'knowledge'],
#  ['experience',
#   'direct',
#   'intimate',
#   'indirect',
#   'conceptual',
#   'mediated',
#   'symbol'],
#  ['know', 'home', 'intimately', 'know', 'country', 'large'],
#  ['longtime',
#   'resident',
#   'minneapolis',
#   'know',
#   'city',
#   'cabdriver',
#   'learns',
#   'find',
#   'way',
#   'geographer',
#   'study',
#   'minneapolis',
#   'know',
#   'city',
#   'conceptually'],
#  ['three', 'kind', 'experiencing'],
#  ['one',
#   'person',
#   'may',
#   'know',
#   'place',
#   'intimately',
#   'well',
#   'conceptually'],
#  ['articulate',
#   'idea',
#   'difficulty',
#   'expressing',
#   'know',
#   'sens',
#   'touch',
#   'taste',
#   'smell',
#   'hearing',
#   'even',
#   'vision'],
#  ['people', 'tend', 'suppress', 'cannot', 'express'],
#  ['experience',
#   'resists',
#   'ready',
#   'communication',
#   'common',
#   'response',
#   'among',
#   'activist',
#   'doer',
#   'deem',
#   'privateeven',
#   'idiosyncraticand',
#   'hence',
#   'unimportant'],
#  ['large',
#   'literature',
#   'environmental',
#   'quality',
#   'relatively',
#   'work',
#   'attempt',
#   'understand',
#   'people',
#   'feel',
#   'space',
#   'place',
#   'take',
#   'account',
#   'different',
#   'mode',
#   'experience',
#   'sensorimotor',
#   'tactile',
#   'visual',
#   'conceptual',
#   'interpret',
#   'space',
#   'place',
#   'image',
#   'complexoften',
#   'ambivalentfeelings'],
#  ['professional',
#   'planner',
#   'urgent',
#   'need',
#   'act',
#   'move',
#   'quickly',
#   'model',
#   'inventory'],
#  ['layman',
#   'accepts',
#   'readily',
#   'charismatic',
#   'planner',
#   'propagandist',
#   'environmental',
#   'slogan',
#   'may',
#   'picked',
#   'medium',
#   'rich',
#   'experiential',
#   'data',
#   'abstraction',
#   'depend',
#   'easily',
#   'forgotten'],
#  ['yet', 'possible', 'articulate', 'subtle', 'human', 'experience'],
#  ['artist', 'triedoften', 'success'],
#  ['work',
#   'literature',
#   'well',
#   'humanistic',
#   'psychology',
#   'philosophy',
#   'anthropology',
#   'geography',
#   'intricate',
#   'world',
#   'human',
#   'experience',
#   'recorded'],
#  ['book',
#   'draw',
#   'attention',
#   'question',
#   'humanist',
#   'posed',
#   'regard',
#   'space',
#   'place'],
#  ['attempt',
#   'systematize',
#   'humanistic',
#   'insight',
#   'display',
#   'conceptual',
#   'frame',
#   'organized',
#   'chapter',
#   'importance',
#   'evident',
#   'u',
#   'thoughtful',
#   'people',
#   'curious',
#   'know',
#   'natureour',
#   'potential',
#   'experiencingbut',
#   'also',
#   'tenant',
#   'earth',
#   'practically',
#   'concerned',
#   'design',
#   'human',
#   'habitat'],
#  ['approach', 'descriptive', 'aiming', 'often', 'suggest', 'conclude'],
#  ['area',
#   'study',
#   'much',
#   'tentative',
#   'perhaps',
#   'statement',
#   'end',
#   'question',
#   'mark',
#   'accompanied',
#   'qualifying',
#   'clause'],
#  ['reader', 'asked', 'supply'],
#  ['exploratory',
#   'work',
#   'virtue',
#   'clarity',
#   'even',
#   'call',
#   'sacrifice',
#   'scholarly',
#   'detail',
#   'qualification'],
#  ['key', 'term', 'book', 'experience'],
#  ['nature', 'experience', 'experiential', 'perspective'],
#  ['experiental', 'perspective'],
#  ['experience',
#   'coverall',
#   'term',
#   'various',
#   'mode',
#   'person',
#   'know',
#   'construct',
#   'reality'],
#  ['mode',
#   'range',
#   'direct',
#   'passive',
#   'sens',
#   'smell',
#   'taste',
#   'touch',
#   'active',
#   'visual',
#   'perception',
#   'indirect',
#   'mode',
#   'symbolization'],
#  ['emotion',
#   'tint',
#   'human',
#   'experience',
#   'including',
#   'high',
#   'flight',
#   'thought'],
#  ['mathematician',
#   'example',
#   'claim',
#   'design',
#   'theorem',
#   'guided',
#   'aesthetic',
#   'criterion',
#   'notion',
#   'elegance',
#   'simplicity',
#   'answer',
#   'human',
#   'need'],
#  ['thought',
#   'tint',
#   'human',
#   'experience',
#   'including',
#   'basic',
#   'sensation',
#   'heat',
#   'cold',
#   'pleasure',
#   'pain'],
#  ['sensation', 'quickly', 'qualified', 'thought', 'one', 'special', 'kind'],
#  ['heat',
#   'suffocating',
#   'prickly',
#   'pain',
#   'sharp',
#   'dull',
#   'irritating',
#   'tease',
#   'brutal',
#   'force'],
#  ['experience', 'directed', 'external', 'world'],
#  ['seeing', 'thinking', 'clearly', 'reach', 'beyond', 'self'],
#  ['feeling', 'ambiguous'],
#  ['paul',
#   'ricoeur',
#   'put',
#   'feeling',
#   'without',
#   'doubt',
#   'intentional',
#   'feeling',
#   'something',
#   'lovable',
#   'hateful',
#   'instance'],
#  ['strange',
#   'intentionality',
#   'one',
#   'hand',
#   'designates',
#   'quality',
#   'felt',
#   'thing',
#   'person',
#   'world',
#   'hand',
#   'manifest',
#   'reveals',
#   'way',
#   'self',
#   'inwardly',
#   'affected'],
#  ['feeling', 'intention', 'affection', 'coincide', 'experience'],
#  ['experience',
#   'connotation',
#   'passivity',
#   'word',
#   'suggests',
#   'person',
#   'undergone',
#   'suffered'],
#  ['experienced', 'man', 'woman', 'one', 'much', 'happened'],
#  ['yet',
#   'speak',
#   'plant',
#   'experience',
#   'even',
#   'lower',
#   'animal',
#   'word',
#   'experience',
#   'seems',
#   'inappropriate'],
#  ['young',
#   'pup',
#   'however',
#   'contrasted',
#   'experienced',
#   'mastiff',
#   'human',
#   'being',
#   'mature',
#   'immature',
#   'depending',
#   'whether',
#   'benefited',
#   'event'],
#  ['experience',
#   'thus',
#   'implies',
#   'ability',
#   'learn',
#   'one',
#   'undergone',
#   'experience',
#   'learn',
#   'mean',
#   'acting',
#   'given',
#   'creating',
#   'given'],
#  ['given', 'cannot', 'known'],
#  ['known',
#   'reality',
#   'construct',
#   'experience',
#   'creation',
#   'feeling',
#   'thought'],
#  ['susanne',
#   'langer',
#   'put',
#   'world',
#   'physic',
#   'essentially',
#   'real',
#   'world',
#   'construed',
#   'mathematical',
#   'abstraction',
#   'world',
#   'sense',
#   'real',
#   'world',
#   'construed',
#   'abstraction',
#   'sense',
#   'organ',
#   'immediately',
#   'furnish'],
#  ['experience', 'overcoming', 'peril'],
#  ['word',
#   'experience',
#   'share',
#   'common',
#   'root',
#   'per',
#   'experiment',
#   'expert',
#   'perilous'],
#  ['experience',
#   'active',
#   'sense',
#   'requires',
#   'one',
#   'venture',
#   'forth',
#   'unfamiliar',
#   'experiment',
#   'elusive',
#   'uncertain'],
#  ['become', 'expert', 'one', 'must', 'dare', 'confront', 'peril', 'new'],
#  ['one', 'dare'],
#  ['human', 'individual', 'driven'],
#  ['passionate', 'passion', 'token', 'mental', 'force'],
#  ['emotional',
#   'repertoire',
#   'clam',
#   'restricted',
#   'compared',
#   'puppy',
#   'affective',
#   'life',
#   'chimpanzee',
#   'seems',
#   'almost',
#   'varied',
#   'intense',
#   'human'],
#  ['human',
#   'infant',
#   'distinguished',
#   'mammalian',
#   'young',
#   'helplessness',
#   'fearsome',
#   'tantrum'],
#  ['infant',
#   'emotional',
#   'range',
#   'smile',
#   'tantrum',
#   'hint',
#   'potential',
#   'intellectual',
#   'reach'],
#  ['experience', 'compounded', 'feeling', 'thought'],
#  ['human',
#   'feeling',
#   'succession',
#   'discrete',
#   'sensation',
#   'rather',
#   'memory',
#   'anticipation',
#   'able',
#   'wield',
#   'sensory',
#   'impact',
#   'shifting',
#   'stream',
#   'experience',
#   'may',
#   'speak',
#   'life',
#   'feeling',
#   'life',
#   'thought'],
#  ['common',
#   'tendency',
#   'regard',
#   'feeling',
#   'thought',
#   'opposed',
#   'one',
#   'registering',
#   'subjective',
#   'state',
#   'reporting',
#   'objective',
#   'reality'],
#  ['fact',
#   'lie',
#   'near',
#   'two',
#   'end',
#   'experiential',
#   'continuum',
#   'way',
#   'knowing'],
#  ['see', 'think', 'closely', 'related', 'process'],
#  ['english', 'see', 'mean', 'understand'],
#  ['seeing',
#   'long',
#   'recognized',
#   'simple',
#   'recording',
#   'light',
#   'stimulus',
#   'selective',
#   'creative',
#   'process',
#   'environmental',
#   'stimulus',
#   'organized',
#   'flowing',
#   'structure',
#   'provide',
#   'sign',
#   'meaningful',
#   'purposive',
#   'organism'],
#  ['sens', 'smell', 'touch', 'informed', 'mentality'],
#  ['tend', 'slight', 'cognitive', 'power', 'sens'],
#  ['yet',
#   'french',
#   'verb',
#   'savoir',
#   'know',
#   'closely',
#   'related',
#   'english',
#   'savour'],
#  ['taste', 'smell', 'touch', 'capable', 'exquisite', 'refinement'],
#  ['discriminate',
#   'among',
#   'wealth',
#   'sensation',
#   'articulate',
#   'gustatory',
#   'olfactory',
#   'textural',
#   'world'],
#  ['structuring', 'world', 'call', 'intelligence'],
#  ['like',
#   'intellectual',
#   'act',
#   'seeing',
#   'hearing',
#   'sens',
#   'smell',
#   'touch',
#   'improved',
#   'practice',
#   'discern',
#   'significant',
#   'world'],
#  ['human',
#   'adult',
#   'develop',
#   'extraordinary',
#   'sensitivity',
#   'wide',
#   'range',
#   'flower',
#   'fragrance'],
#  ['although',
#   'human',
#   'nose',
#   'far',
#   'le',
#   'acute',
#   'canine',
#   'nose',
#   'detecting',
#   'certain',
#   'odor',
#   'low',
#   'intensity',
#   'people',
#   'may',
#   'responsive',
#   'broader',
#   'range',
#   'odor',
#   'dog'],
#  ['dog',
#   'young',
#   'child',
#   'appreciate',
#   'flower',
#   'fragrance',
#   'way',
#   'human',
#   'adult'],
#  ['young',
#   'childrens',
#   'favorite',
#   'odor',
#   'fruit',
#   'rather',
#   'flow',
#   'er',
#   'fruit',
#   'good',
#   'eat',
#   'preference',
#   'understandable'],
#  ['survival', 'value', 'sensitivity', 'chemical', 'oil', 'wafted', 'flower'],
#  ['clear', 'biological', 'purpose', 'served', 'sensitivity'],
#  ['would',
#   'seem',
#   'nose',
#   'le',
#   'eye',
#   'seek',
#   'enlarge',
#   'comprehend',
#   'world'],
#  ['odor', 'potent', 'biological', 'meaning'],
#  ['body', 'scent', 'example', 'may', 'stimulate', 'sexual', 'activity'],
#  ['hand', 'many', 'human', 'adult', 'find', 'smell', 'decay', 'repulsive'],
#  ['mammal',
#   'nose',
#   'far',
#   'keener',
#   'human',
#   'tolerate',
#   'even',
#   'appreciate',
#   'carrion',
#   'odor',
#   'would',
#   'disgust',
#   'men'],
#  ['young', 'child', 'also', 'appear', 'indifferent', 'fetid', 'smell'],
#  ['langer',
#   'suggests',
#   'odor',
#   'decay',
#   'memento',
#   'mori',
#   'grown',
#   'people',
#   'carry',
#   'meaning',
#   'animal',
#   'small',
#   'child'],
#  ['touch', 'articulates', 'another', 'kind', 'complex', 'world'],
#  ['human', 'hand', 'peerless', 'strength', 'agility', 'sensitivity'],
#  ['primate',
#   'including',
#   'man',
#   'use',
#   'hand',
#   'know',
#   'comfort',
#   'member',
#   'specie',
#   'man',
#   'also',
#   'us',
#   'hand',
#   'explore',
#   'physical',
#   'environment',
#   'carefully',
#   'differentiating',
#   'feel',
#   'bark',
#   'stone'],
#  ['human',
#   'adult',
#   'dislike',
#   'sticky',
#   'matter',
#   'skin',
#   'perhaps',
#   'destroys',
#   'skin',
#   'power',
#   'discernment'],
#  ['substance',
#   'like',
#   'dirty',
#   'spectacle',
#   'dulls',
#   'faculty',
#   'exploration'],
#  ['modern',
#   'architectural',
#   'environment',
#   'may',
#   'cater',
#   'eye',
#   'often',
#   'lack',
#   'pungent',
#   'personality',
#   'varied',
#   'plea',
#   'ant',
#   'odor',
#   'give'],
#  ['odor',
#   'lend',
#   'character',
#   'object',
#   'place',
#   'making',
#   'distinctive',
#   'easier',
#   'identify',
#   'remember'],
#  ['odor', 'important', 'human', 'being'],
#  ['even',
#   'spoken',
#   'olfactory',
#   'world',
#   'fragrance',
#   'scent',
#   'constitute',
#   'world'],
#  ['world',
#   'suggests',
#   'spatial',
#   'structure',
#   'olfactory',
#   'world',
#   'would',
#   'one',
#   'odor',
#   'spatially',
#   'disposed',
#   'simply',
#   'one',
#   'appear',
#   'random',
#   'succession',
#   'inchoate',
#   'mixture'],
#  ['sens', 'sight', 'touch', 'provide', 'spatially', 'organized', 'world'],
#  ['possible',
#   'argue',
#   'taste',
#   'odor',
#   'even',
#   'hearing',
#   'cannot',
#   'give',
#   'u',
#   'sense',
#   'space'],
#  ['question',
#   'largely',
#   'academic',
#   'people',
#   'function',
#   'five',
#   'sens',
#   'constantly',
#   'reinforce',
#   'provide',
#   'intricately',
#   'ordered',
#   'emotion',
#   'charged',
#   'world',
#   'live'],
#  ['taste',
#   'example',
#   'almost',
#   'invariably',
#   'involves',
#   'touch',
#   'smell',
#   'tongue',
#   'roll',
#   'around',
#   'hard',
#   'candy',
#   'exploring',
#   'shape',
#   'olfactory',
#   'sense',
#   'register',
#   'caramel',
#   'flavor'],
#  ['hear', 'smell', 'something', 'often', 'also', 'see'],
#  ['sensory',
#   'organ',
#   'experience',
#   'enable',
#   'human',
#   'being',
#   'strong',
#   'feeling',
#   'space',
#   'spatial',
#   'quality'],
#  ['answer', 'kinesthesia', 'sight', 'touch'],
#  ['movement',
#   'simple',
#   'ability',
#   'kick',
#   'one',
#   'leg',
#   'stretch',
#   'one',
#   'arm',
#   'basic',
#   'awareness',
#   'space'],
#  ['space', 'experienced', 'directly', 'room', 'move'],
#  ['moreover',
#   'shifting',
#   'one',
#   'place',
#   'another',
#   'person',
#   'acquires',
#   'sense',
#   'direction'],
#  ['forward',
#   'backward',
#   'sideways',
#   'experientially',
#   'differentiated',
#   'known',
#   'subconsciously',
#   'act',
#   'motion'],
#  ['space',
#   'assumes',
#   'rough',
#   'coordinate',
#   'frame',
#   'centered',
#   'mobile',
#   'purposive',
#   'self'],
#  ['human',
#   'eye',
#   'bifocal',
#   'overlap',
#   'stereoscopic',
#   'capacity',
#   'provide',
#   'people',
#   'vivid',
#   'space',
#   'three',
#   'dimension'],
#  ['experience', 'however', 'necessary'],
#  ['take',
#   'time',
#   'practice',
#   'infant',
#   'person',
#   'born',
#   'blind',
#   'sight',
#   'recently',
#   'restored',
#   'perceive',
#   'world',
#   'made',
#   'stable',
#   'threedimensional',
#   'object',
#   'arranged',
#   'space',
#   'rather',
#   'shifting',
#   'pattern',
#   'color'],
#  ['touching',
#   'manipulating',
#   'thing',
#   'hand',
#   'yield',
#   'world',
#   'objectsobjects',
#   'retain',
#   'constancy',
#   'shape',
#   'size'],
#  ['reaching',
#   'thing',
#   'playing',
#   'disclose',
#   'separateness',
#   'relative',
#   'spacing'],
#  ['purposive',
#   'movement',
#   'perception',
#   'visual',
#   'haptic',
#   'give',
#   'human',
#   'being',
#   'familiar',
#   'world',
#   'disparate',
#   'object',
#   'space'],
#  ['place', 'special', 'kind', 'object'],
#  ['concretion',
#   'value',
#   'though',
#   'valued',
#   'thing',
#   'handled',
#   'carried',
#   'easily',
#   'object',
#   'one',
#   'dwell'],
#  ['space', 'noted', 'given', 'ability', 'move'],
#  ['movement', 'often', 'directed', 'toward', 'repulsed', 'object', 'place'],
#  ['hence',
#   'space',
#   'variously',
#   'experienced',
#   'relative',
#   'location',
#   'object',
#   'place',
#   'distance',
#   'expanse',
#   'separate',
#   'link',
#   'place',
#   'abstractlyas',
#   'area',
#   'defined',
#   'network',
#   'place'],
#  ['taste',
#   'smell',
#   'skin',
#   'sensitivity',
#   'hearing',
#   'cannot',
#   'individually',
#   'perhaps',
#   'even',
#   'together',
#   'make',
#   'u',
#   'aware',
#   'spacious',
#   'external',
#   'world',
#   'inhabited',
#   'object'],
#  ['combination',
#   'spatializing',
#   'faculty',
#   'sight',
#   'touch',
#   'however',
#   'essentially',
#   'non',
#   'distancing',
#   'sens',
#   'greatly',
#   'en',
#   'rich',
#   'apprehension',
#   'world',
#   'spatial',
#   'geometrical',
#   'character'],
#  ['taste', 'label', 'flavor', 'sharp', 'others', 'flat'],
#  ['meaning',
#   'geometrical',
#   'term',
#   'enhanced',
#   'metaphorical',
#   'use',
#   'realm',
#   'taste'],
#  ['odor', 'capable', 'suggesting', 'mass', 'volume'],
#  ['odor',
#   'like',
#   'musk',
#   'tuberosa',
#   'heavy',
#   'whereas',
#   'others',
#   'delicate',
#   'thin',
#   'light'],
#  ['carnivore',
#   'depend',
#   'acute',
#   'sense',
#   'smell',
#   'track',
#   'prey',
#   'may',
#   'nose',
#   'capable',
#   'articulating',
#   'spatially',
#   'structured',
#   'worldat',
#   'least',
#   'one',
#   'differentiated',
#   'direction',
#   'distance'],
#  ['human', 'nose', 'much', 'atrophied', 'organ'],
#  ['depend',
#   'eye',
#   'locate',
#   'source',
#   'danger',
#   'appeal',
#   'support',
#   'prior',
#   'visual',
#   'world',
#   'human',
#   'nose',
#   'discern',
#   'direction',
#   'estimate',
#   'relative',
#   'distance',
#   'strength',
#   'odor'],
#  ['person',
#   'handle',
#   'object',
#   'feel',
#   'texture',
#   'geometric',
#   'property',
#   'size',
#   'shape'],
#  ['apart',
#   'manipulation',
#   'skin',
#   'sensitivity',
#   'contribute',
#   'human',
#   'spatial',
#   'experience'],
#  ['though', 'limited', 'way'],
#  ['skin', 'register', 'sensation'],
#  ['report', 'state', 'time', 'object', 'pressing'],
#  ['skin', 'however', 'distance', 'sensor'],
#  ['respect',
#   'tactile',
#   'perception',
#   'opposite',
#   'extreme',
#   'visual',
#   'perception'],
#  ['skin',
#   'able',
#   'con',
#   'vey',
#   'certain',
#   'spatial',
#   'idea',
#   'without',
#   'support',
#   'sens',
#   'depending',
#   'structure',
#   'body',
#   'ability',
#   'move'],
#  ['relative',
#   'length',
#   'example',
#   'registered',
#   'different',
#   'part',
#   'body',
#   'touched',
#   'time'],
#  ['skin', 'convey', 'sense', 'volume', 'mass'],
#  ['one',
#   'doubt',
#   'entrance',
#   'warm',
#   'bath',
#   'give',
#   'skin',
#   'massive',
#   'feeling',
#   'prick',
#   'pin'],
#  ['skin',
#   'come',
#   'contact',
#   'flattish',
#   'object',
#   'judge',
#   'approximately',
#   'shape',
#   'size'],
#  ['micro',
#   'level',
#   'roughness',
#   'smoothness',
#   'geometric',
#   'property',
#   'skin',
#   'easily',
#   'recognizes'],
#  ['object', 'also', 'hard', 'soft'],
#  ['tactile',
#   'perception',
#   'differentiates',
#   'characteristic',
#   'spatiogeometric',
#   'evidence'],
#  ['thus',
#   'hard',
#   'object',
#   'retains',
#   'shape',
#   'pressure',
#   'whereas',
#   'soft',
#   'object'],
#  ['sense', 'distance', 'space', 'created', 'ability', 'hear'],
#  ['world',
#   'sound',
#   'would',
#   'appear',
#   'spatially',
#   'structured',
#   'though',
#   'sharpness',
#   'visual',
#   'world'],
#  ['possible',
#   'blind',
#   'man',
#   'hear',
#   'hand',
#   'barely',
#   'move',
#   'lack',
#   'sense',
#   'space',
#   'perhaps',
#   'person',
#   'sound',
#   'bodily',
#   'sensation',
#   'cue',
#   'character',
#   'environment'],
#  ['people', 'severely', 'handicapped'],
#  ['given',
#   'sight',
#   'power',
#   'move',
#   'handle',
#   'thing',
#   'sound',
#   'greatly',
#   'enrich',
#   'human',
#   'feeling',
#   'space'],
#  ['human',
#   'ear',
#   'flexible',
#   'le',
#   'equipped',
#   'discern',
#   'direction',
#   'say',
#   'ear',
#   'wolf'],
#  ['turning', 'head', 'person', 'roughly', 'tell', 'direction', 'sound'],
#  ['people',
#   'subconsciously',
#   'aware',
#   'source',
#   'noise',
#   'awareness',
#   'construe',
#   'auditory',
#   'space'],
#  ['sound',
#   'though',
#   'vaguely',
#   'located',
#   'convey',
#   'strong',
#   'sense',
#   'size',
#   'volume',
#   'distance'],
#  ['example',
#   'empty',
#   'cathedral',
#   'sound',
#   'footstep',
#   'tapping',
#   'sharply',
#   'stone',
#   'floor',
#   'creates',
#   'impression',
#   'cavernous',
#   'vastness'],
#  ['power',
#   'sound',
#   'evoke',
#   'distance',
#   'albert',
#   'camus',
#   'wrote',
#   'algeria',
#   'dog',
#   'heard',
#   'barking',
#   'night',
#   'distance',
#   'ten',
#   'time',
#   'greater',
#   'europe'],
#  ['noise', 'thus', 'take', 'nostalgia', 'unknown', 'cramped', 'country'],
#  ['blind',
#   'people',
#   'develop',
#   'acute',
#   'sensitivity',
#   'sound',
#   'able',
#   'use',
#   'reverberation',
#   'evaluate',
#   'environment',
#   'spatial',
#   'character'],
#  ['people', 'see', 'le', 'sensitive', 'auditory', 'cue', 'dependent'],
#  ['human',
#   'being',
#   'learn',
#   'however',
#   'relate',
#   'sound',
#   'distance',
#   'act',
#   'speaking'],
#  ['alter',
#   'tone',
#   'voice',
#   'soft',
#   'loud',
#   'intimate',
#   'public',
#   'accordance',
#   'perceived',
#   'physical',
#   'social',
#   'distance',
#   'others'],
#  ['volume',
#   'phrasing',
#   'voice',
#   'well',
#   'try',
#   'say',
#   'constant',
#   'reminder',
#   'proximity',
#   'distance'],
#  ['sound', 'evoke', 'spatial', 'impression'],
#  ['reverberation',
#   'thunder',
#   'voluminous',
#   'squeaking',
#   'chalk',
#   'slate',
#   'pinched',
#   'thin'],
#  ['low',
#   'musical',
#   'tone',
#   'voluminous',
#   'whereas',
#   'high',
#   'pitch',
#   'seem',
#   'thin',
#   'penetrating'],
#  ['musicologist', 'speak', 'musical', 'space'],
#  ['spatial',
#   'illusion',
#   'created',
#   'music',
#   'quite',
#   'apart',
#   'phenomenon',
#   'volume',
#   'fact',
#   'movement',
#   'logically',
#   'involves',
#   'space'],
#  ['music', 'often', 'said', 'form'],
#  ['musical', 'form', 'may', 'generate', 'reassuring', 'sense', 'orientation'],
#  ['musicologist',
#   'roberto',
#   'gerhard',
#   'form',
#   'music',
#   'mean',
#   'knowing',
#   'every',
#   'moment',
#   'exactly',
#   'one'],
#  ['consciousness', 'form', 'really', 'sense', 'orientation'],
#  ['various', 'sensory', 'space', 'bear', 'little', 'likeness'],
#  ['visual',
#   'space',
#   'vividness',
#   'size',
#   'differs',
#   'strikingly',
#   'diffuse',
#   'auditory',
#   'tactilesensorimotor',
#   'space'],
#  ['blind',
#   'man',
#   'whose',
#   'knowledge',
#   'space',
#   'derives',
#   'auditory',
#   'tactile',
#   'cue',
#   'cannot',
#   'time',
#   'appreciate',
#   'visual',
#   'world',
#   'gain',
#   'sight'],
#  ['vaulted',
#   'interior',
#   'cathedral',
#   'sensation',
#   'slipping',
#   'warm',
#   'bath',
#   'signify',
#   'volume',
#   'spaciousness',
#   'although',
#   'experience',
#   'hardly',
#   'comparable'],
#  ['likewise',
#   'meaning',
#   'distance',
#   'varied',
#   'experiential',
#   'mode',
#   'acquire',
#   'feel',
#   'distance',
#   'effort',
#   'moving',
#   'one',
#   'place',
#   'another',
#   'need',
#   'project',
#   'voice',
#   'hearing',
#   'dog',
#   'bark',
#   'night',
#   'recognizing',
#   'environmental',
#   'cue',
#   'visual',
#   'perspective'],
#  ['organization', 'human', 'space', 'uniquely', 'dependent', 'sight'],
#  ['sens', 'expand', 'enrich', 'visual', 'space'],
#  ['thus',
#   'sound',
#   'enlarges',
#   'one',
#   'spatial',
#   'awareness',
#   'include',
#   'area',
#   'behind',
#   'head',
#   'cannot',
#   'seen'],
#  ['important', 'sound', 'dramatizes', 'spatial', 'experience'],
#  ['soundless',
#   'space',
#   'feel',
#   'calm',
#   'lifeless',
#   'despite',
#   'visible',
#   'flow',
#   'activity',
#   'watching',
#   'event',
#   'binoculars',
#   'television',
#   'screen',
#   'sound',
#   'turned',
#   'city',
#   'muffled',
#   'fresh',
#   'blanket',
#   'snow'],
#  ['human', 'space', 'reflect', 'quality', 'human', 'sens', 'mentality'],
#  ['mind', 'frequently', 'extrapolates', 'beyond', 'sensory', 'evidence'],
#  ['consider', 'notion', 'vastness'],
#  ['vastness', 'ocean', 'directly', 'perceived'],
#  ['think',
#   'ocean',
#   'whole',
#   'say',
#   'william',
#   'james',
#   'multiplying',
#   'mentally',
#   'impression',
#   'get',
#   'moment',
#   'sea'],
#  ['continent', 'separate', 'new', 'york', 'san', 'francisco'],
#  ['distance',
#   'order',
#   'apprehended',
#   'numerical',
#   'verbal',
#   'symbol',
#   'computed',
#   'example',
#   'day',
#   'journey'],
#  ['symbol', 'often', 'give', 'u', 'emotional', 'effect', 'perception'],
#  ['ex',
#   'pressions',
#   'abysmal',
#   'vault',
#   'heaven',
#   'endless',
#   'expanse',
#   'ocean',
#   'etc',
#   'summarize',
#   'many',
#   'computation',
#   'imagination',
#   'give',
#   'sense',
#   'enormous',
#   'horizon'],
#  ['someone',
#   'mathematical',
#   'imagination',
#   'blaise',
#   'pascal',
#   'look',
#   'sky',
#   'appalled',
#   'infinite',
#   'expanse'],
#  ['blind', 'men', 'able', 'know', 'meaning', 'distant', 'horizon'],
#  ['extrapolate',
#   'experience',
#   'auditory',
#   'space',
#   'freedom',
#   'movement',
#   'envisage',
#   'mind',
#   'eye',
#   'panoramic',
#   'view',
#   'boundless',
#   'space'],
#  ['blind',
#   'man',
#   'told',
#   'william',
#   'james',
#   'thought',
#   'seeing',
#   'people',
#   'could',
#   'enjoy',
#   'view',
#   'mountain',
#   'top'],
#  ['mind',
#   'discerns',
#   'geometric',
#   'design',
#   'principle',
#   'spatial',
#   'organization',
#   'environment'],
#  ['example',
#   'dakota',
#   'indian',
#   'find',
#   'evidence',
#   'circular',
#   'form',
#   'nature',
#   'nearly',
#   'everywhere',
#   'shape',
#   'bird',
#   'nest',
#   'course',
#   'star'],
#  ['contrast',
#   'pueblo',
#   'indian',
#   'american',
#   'southwest',
#   'tend',
#   'see',
#   'space',
#   'rectangular',
#   'geometry'],
#  ['example',
#   'construed',
#   'space',
#   'depends',
#   'power',
#   'mind',
#   'extrapolate',
#   'far',
#   'beyond',
#   'sense',
#   'data'],
#  ['space', 'lie', 'conceptual', 'end', 'experiential', 'continuum'],
#  ['three',
#   'principal',
#   'type',
#   'large',
#   'area',
#   'overlap',
#   'existthe',
#   'mythical',
#   'pragmatic',
#   'abstract',
#   'theoretical'],
#  ['mythical',
#   'space',
#   'conceptual',
#   'schema',
#   'also',
#   'pragmatic',
#   'space',
#   'sense',
#   'within',
#   'schema',
#   'large',
#   'number',
#   'practical',
#   'activity',
#   'planting',
#   'harvesting',
#   'crop',
#   'ordered'],
#  ['difference',
#   'mythical',
#   'pragmatic',
#   'space',
#   'latter',
#   'defined',
#   'limited',
#   'set',
#   'economic',
#   'activity'],
#  ['recognition',
#   'pragmatic',
#   'space',
#   'belt',
#   'poor',
#   'rich',
#   'soil',
#   'course',
#   'intellectual',
#   'achievement'],
#  ['ingenious',
#   'person',
#   'try',
#   'describe',
#   'soil',
#   'pattern',
#   'cartographically',
#   'mean',
#   'symbol',
#   'move',
#   'toward',
#   'conceptual',
#   'mode',
#   'occurs'],
#  ['western',
#   'world',
#   'system',
#   'geometrythat',
#   'highly',
#   'abstract',
#   'spaceshave',
#   'created',
#   'primal',
#   'spatial',
#   'experience'],
#  ['thus',
#   'sensorimotor',
#   'tac',
#   'tile',
#   'experience',
#   'would',
#   'seem',
#   'lie',
#   'root',
#   'euclid',
#   'theorem',
#   'concerning',
#   'shape',
#   'congruence',
#   'parallelism',
#   'distant',
#   'line',
#   'visual',
#   'perception',
#   'basis',
#   'projective',
#   'geometry'],
#  ['human',
#   'being',
#   'discern',
#   'geometric',
#   'pattern',
#   'nature',
#   'create',
#   'abstract',
#   'space',
#   'mind',
#   'also',
#   'try',
#   'embody',
#   'feeling',
#   'image',
#   'thought',
#   'tangible',
#   'material'],
#  ['result',
#   'sculptural',
#   'architectural',
#   'space',
#   'large',
#   'scale',
#   'planned',
#   'city'],
#  ['progress',
#   'inchoate',
#   'feeling',
#   'space',
#   'fleeting',
#   'discernment',
#   'nature',
#   'public',
#   'material',
#   'reification'],
#  ['place', 'type', 'object'],
#  ['place', 'object', 'define', 'space', 'giving', 'geometric', 'personality'],
#  ['neither',
#   'newborn',
#   'infant',
#   'man',
#   'gain',
#   'sight',
#   'lifetime',
#   'blindness',
#   'immediately',
#   'recognize',
#   'geometric',
#   'shape',
#   'triangle'],
#  ['triangle', 'first', 'space', 'blurred', 'image'],
#  ['recognizing',
#   'triangle',
#   'requires',
#   'prior',
#   'identification',
#   'cornersthat',
#   'place'],
#  ['neighborhood',
#   'first',
#   'confusion',
#   'image',
#   'new',
#   'resident',
#   'blurred',
#   'space'],
#  ['learning',
#   'know',
#   'neighborhood',
#   'requires',
#   'identification',
#   'significant',
#   'locality',
#   'street',
#   'corner',
#   'architectural',
#   'landmark',
#   'within',
#   'neighborhood',
#   'space'],
#  ['object', 'place', 'center', 'value'],
#  ['attract', 'repel', 'finely', 'shaded', 'degree'],
#  ['attend', 'even', 'momentarily', 'acknowledge', 'reality', 'value'],
#  ['infant',
#   'world',
#   'lack',
#   'permanent',
#   'object',
#   'dominated',
#   'fleeting',
#   'impression'],
#  ['impression',
#   'given',
#   'u',
#   'sens',
#   'acquire',
#   'stability',
#   'object',
#   'place'],
#  ['intelligence', 'manifest', 'different', 'type', 'achievement'],
#  ['one', 'ability', 'recognize', 'feel', 'deeply', 'particular'],
#  ['distinction',
#   'schematic',
#   'world',
#   'animal',
#   'live',
#   'schematic',
#   'world',
#   'human',
#   'being',
#   'also',
#   'richly',
#   'populated',
#   'particular',
#   'enduring',
#   'thing'],
#  ['particular',
#   'thing',
#   'value',
#   'may',
#   'given',
#   'name',
#   'tea',
#   'set',
#   'wedgewood',
#   'chair',
#   'chippendale'],
#  ['people', 'proper', 'name'],
#  ['particular',
#   'thing',
#   'may',
#   'well',
#   'first',
#   'permanent',
#   'object',
#   'infant',
#   'world',
#   'unstable',
#   'impression'],
#  ['object',
#   'valued',
#   'crystal',
#   'glass',
#   'recognized',
#   'unique',
#   'shape',
#   'decorative',
#   'design',
#   'ring',
#   'lightly',
#   'tapped'],
#  ['city',
#   'san',
#   'francisco',
#   'recognized',
#   'unique',
#   'setting',
#   'topography',
#   'skyline',
#   'odor',
#   'street',
#   'noise',
#   'object',
#   'place',
#   'achieves',
#   'concrete',
#   'reality',
#   'experience',
#   'total',
#   'sens',
#   'well',
#   'active',
#   'reflective',
#   'mind'],
#  ['long',
#   'residence',
#   'enables',
#   'u',
#   'know',
#   'place',
#   'intimately',
#   'yet',
#   'image',
#   'may',
#   'lack',
#   'sharpness',
#   'unless',
#   'also',
#   'see',
#   'outside',
#   'reflect',
#   'upon',
#   'experience'],
#  ['another',
#   'place',
#   'may',
#   'lack',
#   'weight',
#   'reality',
#   'know',
#   'outsidethrough',
#   'eye',
#   'tourist',
#   'reading',
#   'guidebook'],
#  ['characteristic',
#   'symbolmaking',
#   'human',
#   'specie',
#   'member',
#   'become',
#   'passionately',
#   'attached',
#   'place',
#   'enormous',
#   'size',
#   'nationstate',
#   'limited',
#   'direct',
#   'experience']]

# %% [markdown]
# ## construimos redes!

# %%
import networkx as nx

## función que construye redes
def GoW_adj(text_clean):
    G=nx.Graph()
    for sentence in text_clean:
        if len(sentence)>1:
            pairs=list(zip(sentence,sentence[1:]))
            for pair in pairs:
                if G.has_edge(pair[0],pair[1])==False:
                    G.add_edge(pair[0],pair[1],weight=1)
                else:
                    x=G[pair[0]][pair[1]]['weight']
                    G[pair[0]][pair[1]]['weight']=x+1
        
    return G

# %%
G = GoW_adj(text)

# %%
## número de nodos (palabras)

len(G)
# Out:
# 1345

# %%
## visualizamos
import matplotlib.pyplot as plt

pos = nx.spring_layout(G)

fig, ax = plt.subplots(dpi=800)
 
labels = {i:i for i in G.nodes()}
    
nx.draw_networkx_nodes(G, pos, node_size = 50, node_color='orange',node_shape='o',alpha=0.95, linewidths=0.1,cmap=plt.cm.autumn.reversed()) 
nx.draw_networkx_edges(G, pos, alpha=0.5,width=0.25,edge_color='k')
nx.draw_networkx_labels(G,pos,labels,alpha=0.75,font_size=2.5,font_color='k',font_family='monospace')
plt.axis('off')
plt.title('Capítulos 1 and 2',fontsize=9)
#plt.savefig('graph_'+str(areas)+'.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()
